# %%
pip install pandas_datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tickers = ['AAPL', 'MSFT', '^GSPC']

# We would like all available data from 01/01/2000 until 12/31/2016.
start_date = '2015-01-01'
end_date = '2016-12-31'

# User pandas_reader.data.DataReader to load the desired data. As simple as that.
panel_data = data.DataReader('RTSI.ME', 'yahoo', start_date, end_date)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\envs\Note\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-1e4733b472ad> in <module>
#       6
# ...

# %%
df = yf.download(["SBER.ME", 'GAZP.ME', 'YNDX.ME', 'MGNT.ME', 'GMKN.ME',
                  'MTSS.ME', 'PIKK.ME', 'AFLT.ME', 'AFLT.ME', 'RSTI.ME',
                  'RUB=X', 'JPYRUB=X', 'BZ=F', 'IMOEX.ME'], start="2017-01-01", end="2021-01-01")
# Out:
# [*********************100%***********************]  13 of 13 completed

# %%
df.to_csv('moex_data.csv')

# %%
prices = df['Adj Close']

# %%
prices.head()
# Out:
#                AFLT.ME       BZ=F     GAZP.ME      GMKN.ME     IMOEX.ME  \
# Date
# 2017-01-02         NaN        NaN         NaN          NaN          NaN
# 2017-01-03  128.708633  55.470001  119.453156  6927.608887  2285.429932
# 2017-01-04  125.925385  56.459999  119.256218  6893.798828  2263.899902
# 2017-01-05  125.594444  56.889999  116.650513  6778.846191  2220.350098
# 2017-01-06  124.151909  57.099998  116.726257  6788.989746  2213.929932
#
#             JPYRUB=X      MGNT.ME     MTSS.ME     PIKK.ME   RSTI.ME  \
# Date
# 2017-01-02   0.52381          NaN         NaN         NaN       NaN
# 2017-01-03   0.52161  8697.368164  159.468582  247.140640  1.060553
# 2017-01-04   0.51787  8600.023438  157.434631  245.614563  1.069071
# 2017-01-05   0.51493  8335.583008  158.163223  243.155853  1.075143
# 2017-01-06   0.51498  8354.746094  156.038177  244.173248  1.091455
#
#                 RUB=X     SBER.ME  YNDX.ME
# Date
# 2017-01-02  61.231300         NaN      NaN
# ...

# %%
prices.dropna(inplace=True)
# Out:
# <ipython-input-52-baf5f8f84e27>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prices.dropna(inplace=True)

# %%
prices.head()
# Out:
#                AFLT.ME       BZ=F     GAZP.ME      GMKN.ME     IMOEX.ME  \
# Date
# 2017-01-03  128.708633  55.470001  119.453156  6927.608887  2285.429932
# 2017-01-04  125.925385  56.459999  119.256218  6893.798828  2263.899902
# 2017-01-05  125.594444  56.889999  116.650513  6778.846191  2220.350098
# 2017-01-06  124.151909  57.099998  116.726257  6788.989746  2213.929932
# 2017-01-09  121.453506  54.939999  116.953491  6839.704590  2211.250000
#
#             JPYRUB=X      MGNT.ME     MTSS.ME     PIKK.ME   RSTI.ME  \
# Date
# 2017-01-03   0.52161  8697.368164  159.468582  247.140640  1.060553
# 2017-01-04   0.51787  8600.023438  157.434631  245.614563  1.069071
# 2017-01-05   0.51493  8335.583008  158.163223  243.155853  1.075143
# 2017-01-06   0.51498  8354.746094  156.038177  244.173248  1.091455
# 2017-01-09   0.50943  8292.660156  156.888184  245.021088  1.107857
#
#                 RUB=X     SBER.ME  YNDX.ME
# Date
# 2017-01-03  61.228298  115.255280   1241.0
# ...

# %%
prices.pct_change().iloc[1:,:]
# Out:
#              AFLT.ME      BZ=F   GAZP.ME   GMKN.ME  IMOEX.ME  JPYRUB=X  \
# Date
# 2017-01-04 -0.021624  0.017847 -0.001649 -0.004880 -0.009421 -0.007170
# 2017-01-05 -0.002628  0.007616 -0.021850 -0.016675 -0.019237 -0.005677
# 2017-01-06 -0.011486  0.003691  0.000649  0.001496 -0.002892  0.000097
# 2017-01-09 -0.021735 -0.037828  0.001947  0.007470 -0.001210 -0.010777
# 2017-01-10  0.034514 -0.023662  0.023122  0.027879  0.011867  0.016450
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-22  0.009075 -0.016303  0.028685  0.020642  0.015717  0.015671
# 2020-12-23  0.007253  0.022364  0.007735  0.009924  0.004832  0.016012
# 2020-12-28  0.000288 -0.006641 -0.024354  0.012682  0.002106 -0.025167
# 2020-12-29  0.014397  0.004522  0.015104  0.000085  0.004824 -0.002777
# 2020-12-30  0.012489  0.004893  0.016027  0.001608  0.004382  0.003395
#
#              MGNT.ME   MTSS.ME   PIKK.ME   RSTI.ME     RUB=X   SBER.ME  \
# Date
# ...

# %%
pct_chng = prices.pct_change().iloc[1:,:]

# %%
pct_chng.columns
# Out:
# Index(['AFLT.ME', 'BZ=F', 'GAZP.ME', 'GMKN.ME', 'IMOEX.ME', 'JPYRUB=X',
#        'MGNT.ME', 'MTSS.ME', 'PIKK.ME', 'RSTI.ME', 'RUB=X', 'SBER.ME',
#        'YNDX.ME'],
#       dtype='object')

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(pct_chng[["SBER.ME", 'GAZP.ME', 'YNDX.ME', 'MGNT.ME', 'GMKN.ME',
                  'MTSS.ME', 'PIKK.ME', 'AFLT.ME', 'RSTI.ME', 'RUB=X', 'JPYRUB=X']].corr())
plt.title('Матрица корреляций процентных изменений инстурментов в портфеле')
plt.show()

# %%
start_sum = 80000000
w_bond = 10000000 / total_sum # вес каждого бонда
w_share = 1000000 / total_sum # вес каждой акции
w_cur = 10000000 / total_sum # вес каждой валюты

# %%
5 * w_bond + 10 * w_share + 2 * w_cur
# Out:
# 1.0
